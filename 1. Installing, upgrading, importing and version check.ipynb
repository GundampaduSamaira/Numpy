# %% [markdown]
# # Numpy (Numerical Python)

# %%
# Def: Numpy is a open source python library for Numerical operations.

# Interview Question: What is the difference between python list and Numpy array.
# Ans: 1. Numpy array are faster than the python list.
# 2. Numpy array takes lower memory then the Python list.
# 3. Lists are heterogeneous but numpy array are homogeneous

# Follow up question: Why numpy array are Faster
# Ans: 1.Numpy array store the elements in continuous memory location.
# 2. Numpy array approximately 50x faster then the python list
# 3. Numpy array are good at working with multiprocessors

# Numpy is designed using c, c++ and python

# %%
# Important Operations of Numpy:

# 1. Installing, upgrading, importing and version check
# 2. Create numpy Arrays (1D, 2D, 3D..)
# 3. Special type of numpy array
# 4. Array Shape, reshape and transpose
# 5. Array Size, Datatype, Datatype conversion
# 6. Indexing, slicing and modifications
# 7. Mathematical & Statistical Operations
# 8. Concatination, stacking and splitting numpy array

# %% [markdown]
# ## 1. Installing, Upgrading, Importing and Version Check

# %% [markdown]
# ### Command to Install Numpy Library

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Command to Upgrade Numpy Library

# %%
pip install -U numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importing Numpy Library

# %%
import numpy as np

# %% [markdown]
# ### Checking Numpy Version

# %%
np.__version__
# Out:
# '2.3.5'
